# %% [markdown]
# <a href="https://colab.research.google.com/github/inoculate23/FramePack/blob/main/copy_of_framepack_colab_zho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<font color="white">FramePack Colab【-Zho-制作】**
#
#
# **源代码来自**：[FramePack](https://github.com/lllyasviel/FramePack)、[-Zho-](https://github.com/ZHO-ZHO-ZHO)
#
# **内容制作**：-Zho-（[B站主页](https://space.bilibili.com/484366804) ，[小红书主页](https://www.xiaohongshu.com/user/profile/63f11530000000001001e0c8?xhsshare=CopyLink&appuid=63f11530000000001001e0c8&apptime=1690528872)6116270352）
#
# **欢迎大家**：关注 + 一键三连+充电支持 ~
#
# **使用方法**：文件 - 在云端保存一份副本、代码执行程序 - 全部运行 - 点击链接进入界面即可

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# !pip install -r requirements.txt
# !git clone https://github.com/lllyasviel/FramePack
# %cd /content/FramePack
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# fatal: destination path 'FramePack' already exists and is not an empty directory.
# /content/FramePack
# ...

# %%
# %cd /content/FramePack
# !python demo_gradio_f1.py --share
# Out:
# /content/FramePack
# 2025-05-06 11:28:00.745876: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746530881.018710    1162 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746530881.091159    1162 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-06 11:28:01.681182: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
